# %% [markdown]
# # Lab CNYT
#
# Andres F. Parra Q.

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ## Cómo graficar una esfera, un punto, una flecha y cómo hacer una etiqueta

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
phi, theta = np.mgrid[0 : 2 * np.pi : 0.1, 0 : np.pi : 0.1]  # Equivale a hacer un doble for
# Para pasar de coordenadas esféricas (phi, theta) a coordenadas cartesianas (x, y, z):
x = np.cos(phi) * np.sin(theta)
y = np.sin(phi) * np.sin(theta)
z = np.cos(theta)
# Para graficar la esfera (estructura de alambre):
ax.plot_wireframe(x, y, z, color='brown', rstride=2, cstride=2, linewidth=0.5, alpha=0.8)
# Para graficar un punto cualquiera en el espacio 3d, en este caso (2, -2, 1):
ax.scatter(2, -2, 1, color='red', s=10) # El valor de s modifica el grosor del punto
# Para hacer una etiqueta, en este caso sobre el punto (2, -2, 1):
ax.text(2, -2, 1, 'Punto', color='black')
# Para graficar una flecha, en este caso del origen al punto (2, -2, 1):
ax.quiver(0, 0, 0, 2, -2, 1, color='blue')
# Nombres de los ejes
ax.set_xlabel('Eje X')
ax.set_ylabel('Eje Y')
ax.set_zlabel('Eje Z')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Prueba

# %%
paises = {"alemania":[52.52,13.41],
       "japon":[35.61,139.70],
       "canada":[56.13,106.34],
       "españa":[40.41,3.70],
       "mexico":[19.42,99.12],
       "suiza":[46.81,8.22],
       "noruega":[60.47,8.46],
       "usa":[34.05,118.24],}

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
phi, theta = np.mgrid[0 : 2 * np.pi : 0.1, 0 : np.pi : 0.1]  # Equivale a hacer un doble for
# Para pasar de coordenadas esféricas (phi, theta) a coordenadas cartesianas (x, y, z):
x = np.cos(phi) * np.sin(theta)
y = np.sin(phi) * np.sin(theta)
z = np.cos(theta)
# Para graficar la esfera (estructura de alambre):
ax.plot_wireframe(x, y, z, color='pink', rstride=2, cstride=2, linewidth=0.5, alpha=0.8)

for pais in paises:

    lat = paises.get(pais)[0]* (np.pi / 180)
    lon = paises.get(pais)[1]* (np.pi / 180)
    
    xp = np.sin(lat) * np.cos(lon) 
    zp = np.sin(lat) * np.sin(lon)
    yp = np.cos(lat)


    # Para graficar un punto cualquiera en el espacio 3d, en este caso (2, -2, 1):
    ax.scatter(xp, yp, zp, color='red', s=10) # El valor de s modifica el grosor del punto
    # Para hacer una etiqueta, en este caso sore el punto (2, -2, 1):
    ax.text(xp, yp, zp, pais, color='black')
    # Para graficar una flecha, en este caso del origen al punto (2, -2, 1):
    # ax.quiver(0, 0, 0, 2, -2, 1, color='blue')
    # Nombres de los ejes
    ax.set_xlabel('Eje X')
    ax.set_ylabel('Eje Y')
    ax.set_zlabel('Eje Z')
    plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def carttopolar (alpha:int, betha:int):
    # Get number for parts
    lon = np.angle(betha) - np.angle(alpha)
    lat = 2 * (np.arctan2 ( np.abs(betha) , np.abs(alpha) ))
    
    xp = np.sin(lat) * np.cos(lon) 
    zp = np.sin(lat) * np.sin(lon)
    yp = np.cos(lat)
    
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    phi, theta = np.mgrid[0 : 2 * np.pi : 0.1, 0 : np.pi : 0.1]  # Equivale a hacer un doble for
    # Para pasar de coordenadas esféricas (phi, theta) a coordenadas cartesianas (x, y, z):
    x = np.cos(phi) * np.sin(theta)
    y = np.sin(phi) * np.sin(theta)
    z = np.cos(theta)
    # Para graficar la esfera (estructura de alambre):
    ax.plot_wireframe(x, y, z, color='pink', rstride=2, cstride=2, linewidth=0.5, alpha=0.8)
    
    # Para graficar un punto cualquiera en el espacio 3d, en este caso (2, -2, 1):
    ax.scatter(xp, yp, zp, color='red', s=10) # El valor de s modifica el grosor del punto
    # Para hacer una etiqueta, en este caso sore el punto (2, -2, 1):
    ax.text(xp, yp, zp, "a", color='black')
    # Para graficar una flecha, en este caso del origen al punto (2, -2, 1):
    # ax.quiver(0, 0, 0, 2, -2, 1, color='blue')
    # Nombres de los ejes
    ax.set_xlabel('Eje X')
    ax.set_ylabel('Eje Y')
    ax.set_zlabel('Eje Z')
    plt.show()

# %%
alpha = (np.sqrt(3)+1j)/4

betha = (np.sqrt(3)/2*np.sqrt(2)) - np.sqrt(3)*1j/2*np.sqrt(2)

carttopolar(alpha, betha)
# Out:
# <img src="data:image/png;base64,..." width="640">
